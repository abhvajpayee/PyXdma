# %%
# !pushd ../; ./install.sh; popd
# Out:
# ~/devel/PyPci-0.1.0 ~/devel/PyPci-0.1.0/docs
# running clean
# running sdist
# running check
# reading manifest template 'MANIFEST.in'
# ...
# writing manifest file 'MANIFEST'
# creating PyPci-0.1.0
# creating PyPci-0.1.0/PyPci
# creating PyPci-0.1.0/PyPci/include
# creating PyPci-0.1.0/PyPci/include/driver
# creating PyPci-0.1.0/PyPci/include/lib
# creating PyPci-0.1.0/docs
# creating PyPci-0.1.0/docs/.ipynb_checkpoints
# making hard links in PyPci-0.1.0...
# hard linking CHANGES.txt -> PyPci-0.1.0
# hard linking MANIFEST.in -> PyPci-0.1.0
# hard linking README.txt -> PyPci-0.1.0
# hard linking setup.cfg -> PyPci-0.1.0
# hard linking setup.py -> PyPci-0.1.0
# hard linking PyPci/__init__.py -> PyPci-0.1.0/PyPci
# hard linking PyPci/cpci.pxd -> PyPci-0.1.0/PyPci
# hard linking PyPci/libpcieSMA.cpython-35m-x86_64-linux-gnu.so -> PyPci-0.1.0/PyPci
# hard linking PyPci/libpcieSMA.so -> PyPci-0.1.0/PyPci
# hard linking PyPci/pci.c -> PyPci-0.1.0/PyPci
# ...

# %%
# %%bash
# pushd ../
# python3 setup.py bdist
# popd
# Out:
# ~/devel/PyPci-0.1.0 ~/devel/PyPci-0.1.0/docs
# running bdist
# running bdist_dumb
# running build
# running build_py
# running build_ext
# building 'PyPci.pci' extension
# gcc -pthread -Wno-unused-result -Wsign-compare -DDYNAMIC_ANNOTATIONS_ENABLED=1 -DNDEBUG -O2 -g -pipe -Wall -Werror=format-security -Wp,-D_FORTIFY_SOURCE=2 -fexceptions -fstack-protector-strong --param=ssp-buffer-size=4 -grecord-gcc-switches -specs=/usr/lib/rpm/redhat/redhat-hardened-cc1 -m64 -mtune=generic -D_GNU_SOURCE -fPIC -fwrapv -fPIC -IPyPci -I/usr/lib64/python3.5/site-packages/numpy/core/include -I/usr/include/python3.5m -c PyPci/pci.c -o build/temp.linux-x86_64-3.5/PyPci/pci.o
# gcc -pthread -shared -Wl,-z,relro -specs=/usr/lib/rpm/redhat/redhat-hardened-ld build/temp.linux-x86_64-3.5/PyPci/pci.o -LPyPci -L/usr/lib64 -lpcieSMA -lpython3.5m -o /home/abajpai/devel/PyPci-0.1.0/PyPci/pci.cpython-35m-x86_64-linux-gnu.so
# installing to build/bdist.linux-x86_64/dumb
# running install
# running install_lib
# ...
